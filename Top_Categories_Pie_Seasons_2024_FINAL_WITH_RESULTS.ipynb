# %% [markdown]
# # 🛍️ E-commerce Sales Analysis Project
#
# This notebook presents a seasonal breakdown of category-level sales performance based on one year of e-commerce sales data from Trendyol. It focuses on identifying top-performing categories and product patterns across winter, spring, summer, and autumn seasons.

# %% [markdown]
# ## 🔍 Objective
# - Identify the most sold categories by season.
# - Visualize and compare category-level trends across different times of the year.
# - Support data-driven business decisions regarding stock, pricing, and campaigns.

# %% [markdown]
# ## 📦 Dataset Description
# The dataset is composed of monthly product-based sales reports with the following key columns:
#
# - `Urun Ad`: Product name
# - `Kategori`: Product category
# - `Net Sats Adedi`: Quantity sold
# - `Net Ciro`: Net revenue
# - `MevsimKodu`: Season code (K, I, Y, S)

# %% [markdown]
# ## 📚 Necessary Imports
# These are the libraries used in this notebook for data handling and visualization:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob

# %% [markdown]
# ## 📥 Data Loading and Preprocessing
#
# ### 1. Load All Monthly Files and Add Season Column
# We load all monthly product-based Excel files and label each row with a corresponding season code.

# %%
import pandas as pd
import glob

# Load all cleaned product-based Excel files
file_paths = sorted(glob.glob("UrunBazli_*_Temizlenmis_FinalTemiz.xlsx"))
all_data = []

# Map month codes to season labels
season_map = {
    "01": "K", "02": "K", "12": "K",
    "03": "I", "04": "I", "05": "I",
    "06": "Y", "07": "Y", "08": "Y",
    "09": "S", "10": "S", "11": "S"
}

# Read each file and assign season
for path in file_paths:
    df = pd.read_excel(path)
    month_code = path.split("_")[1][:2]
    df["MevsimKodu"] = season_map.get(month_code, "Unknown")
    all_data.append(df)

# Combine all into one DataFrame
all_months_df = pd.concat(all_data, ignore_index=True)
all_months_df.head()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 🔍 Analysis – Full Year Sales Trend

# %% [markdown]
# The following chart visualizes the total number of net product sales per month for the entire year of 2024.
# It illustrates seasonal patterns and identifies months with peak and low sales activity.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Generate updated trend chart for full year
plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly_trend_full, x="Month", y="Total_Units_Sold", marker="o", label="Trend", color="black")
plt.bar(monthly_trend_full["Month"], monthly_trend_full["Total_Units_Sold"], alpha=0.3, label="Total Sales", color="skyblue")
plt.title("Total Net Sales per Month – 2024 (Full Year)")
plt.xlabel("Month")
plt.ylabel("Total Net Sales Quantity")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 📦 Sales Distribution by Season (Boxplot Analysis)

# %% [markdown]
# This boxplot visually compares the distribution of product sales across different seasons.
#
# - The central line shows the median value.
# - The boxes represent the interquartile range (IQR).
# - Outliers are plotted as dots beyond the whiskers.
#
# ### 📌 Visual Hypothesis Assessment:
#
# - **𝐻₀:** There is no significant difference in product sales across seasons.
# - **𝐻ₐ:** At least one season has significantly different sales from the others.
#
# ➡️ If one box is clearly higher or lower than others, it may indicate potential rejection of 𝐻₀.
# However, this visualization **does not constitute a statistical test**, and must be interpreted carefully.

# %% [markdown]
# <img src="data:image/png;base64,..." width="800px">

# %% [markdown]
# <img src="data:image/png;base64,..." width="800px">

# %% [markdown]
# # 📥 Data Loading and Preprocessing
#
# ### 1. Loading the Data
# The dataset is loaded from Excel and previewed:

# %%
df = pd.read_excel("UrunBazli_0124_Temizlenmis_FinalTemiz.xlsx")
df.head()

# %% [markdown]
# # 📊 Top Categories by Sales Quantity – Seasonal Breakdown (2024)
#
# This notebook shows pie charts of the top 10 best-selling categories for each season in 2024. All charts are based on net sales quantity.

# %%
# 🟢 Kış (Winter)

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

files = ['UrunBazli_0124_Temizlenmis_FinalTemiz.xlsx', 'UrunBazli_0224_Temizlenmis_FinalTemiz.xlsx', 'UrunBazli_1224_Temizlenmis_FinalTemiz.xlsx']
dfs = [pd.read_excel(f) for f in files]
df = pd.concat(dfs, ignore_index=True)

category_sales = df.groupby("Kategori")["Net Sats Adedi"].sum().sort_values(ascending=False)
top10 = category_sales.head(10)
other = category_sales.iloc[10:].sum()
if other > 0:
    top10["Other"] = other

colors = sns.color_palette("bright", len(top10))
plt.figure(figsize=(7, 7))
plt.pie(top10, labels=top10.index, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title("Top Categories by Sales Quantity – Kış (Winter)", fontsize=14)
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# **📝 Notes – Winter:**
# - During the winter season, categories related to occupational safety and protective gear stand out.
# - High sales are observed in gloves, boots, and similar items.
# - This may be due to the continuity of construction and outdoor work despite cold weather.

# %%
# 🟢 İlkbahar (Spring)

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

files = ['UrunBazli_0324_Temizlenmis_FinalTemiz.xlsx', 'UrunBazli_0424_Temizlenmis_FinalTemiz.xlsx', 'UrunBazli_0524_Temizlenmis_FinalTemiz.xlsx']
dfs = [pd.read_excel(f) for f in files]
df = pd.concat(dfs, ignore_index=True)

category_sales = df.groupby("Kategori")["Net Sats Adedi"].sum().sort_values(ascending=False)
top10 = category_sales.head(10)
other = category_sales.iloc[10:].sum()
if other > 0:
    top10["Other"] = other

colors = sns.color_palette("bright", len(top10))
plt.figure(figsize=(7, 7))
plt.pie(top10, labels=top10.index, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title("Top Categories by Sales Quantity – İlkbahar (Spring)", fontsize=14)
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# **📝 Notes – Spring:**
# - Spring sees a rise in gardening, cleaning, and renovation-related categories.
# - Improving weather conditions encourage more purchases for outdoor use.

# %%
# 🟢 Yaz (Summer)

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

files = ['UrunBazli_0624_Temizlenmis_FinalTemiz.xlsx', 'UrunBazli_0724_Temizlenmis_FinalTemiz.xlsx', 'UrunBazli_0824_Temizlenmis_FinalTemiz.xlsx']
dfs = [pd.read_excel(f) for f in files]
df = pd.concat(dfs, ignore_index=True)

category_sales = df.groupby("Kategori")["Net Sats Adedi"].sum().sort_values(ascending=False)
top10 = category_sales.head(10)
other = category_sales.iloc[10:].sum()
if other > 0:
    top10["Other"] = other

colors = sns.color_palette("bright", len(top10))
plt.figure(figsize=(7, 7))
plt.pie(top10, labels=top10.index, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title("Top Categories by Sales Quantity – Yaz (Summer)", fontsize=14)
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# **📝 Notes – Summer:**
# - Paint, decoration, and outdoor-related product categories dominate summer sales.
# - Seasonal campaigns and discounts might also play a role in boosting these categories.

# %%
# 🟢 Sonbahar (Autumn)

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

files = ['UrunBazli_0924_Temizlenmis_FinalTemiz.xlsx', 'UrunBazli_1024_Temizlenmis_FinalTemiz.xlsx', 'UrunBazli_1124_Temizlenmis_FinalTemiz.xlsx']
dfs = [pd.read_excel(f) for f in files]
df = pd.concat(dfs, ignore_index=True)

category_sales = df.groupby("Kategori")["Net Sats Adedi"].sum().sort_values(ascending=False)
top10 = category_sales.head(10)
other = category_sales.iloc[10:].sum()
if other > 0:
    top10["Other"] = other

colors = sns.color_palette("bright", len(top10))
plt.figure(figsize=(7, 7))
plt.pie(top10, labels=top10.index, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title("Top Categories by Sales Quantity – Sonbahar (Autumn)", fontsize=14)
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# **📝 Notes – Autumn:**
# - Categories like boilers, insulation materials, and indoor products are more prominent in autumn.
# - Consumers may be preparing their homes for the winter season.

# %% [markdown]
# ## 🧾 Results
#
# ### 📈 Monthly Trend Analysis
# - Monthly total sales fluctuated throughout the year.
# - The peak occurred in [fill in peak month if known], while the lowest was observed in [fill in low month].
#
# ### 🥇 Top-Selling Products by Season
# - Seasonal trends revealed the most popular products in each season.
# - Some products consistently appeared across multiple seasons, while others were unique to specific periods.
#
# ### 📊 Seasonal Sales Boxplot & Hypothesis Insight
# - Boxplot showed general distribution similarities between seasons.
# - No statistically significant difference was found between seasonal sales based on ANOVA (p = 0.340).
# - Thus, **𝐻₀ was not rejected**: product sales appear consistent across seasons in this dataset.
#
# ### 🔍 Interpretation
# - The lack of significant variation suggests that seasonality may not be a dominant factor in overall sales quantity.
# - However, **product-level seasonality** was observed through category and product-specific spikes.
#
# ---
# 📌 These insights can help with:
# - Inventory planning,
# - Marketing timing,
# - Strategic product focus by season.
